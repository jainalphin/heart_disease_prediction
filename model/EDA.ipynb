# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('heart.csv')

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
snplot =sns.countplot(df['target'])
for i in snplot.patches:
    percentage = '{:1f}%'.format(100*i.get_height()/len(df['target']))
    x = i.get_x() + i.get_width() / 2
    y=i.get_height()
    snplot.annotate(percentage,(x,y),ha='center',va='center',xytext=(0,10),textcoords = 'offset points')

# %%
snplot=sns.countplot(data=df,x='sex',hue='target')
for i in snplot.patches:
    percentage = '{:.2f}%'.format(100*i.get_height()/len(df['sex']))
    x = i.get_x() + i.get_width() / 2
    y=i.get_height()
    snplot.annotate(percentage,(x,y),ha='center',va='center',xytext=(0,10),textcoords = 'offset points')

# %%
snplot =sns.countplot(data=df,x='cp',hue='target')
for i in snplot.patches:
    percentage = '{:.2f}%'.format(100*i.get_height()/len(df['cp']))
    x = i.get_x() + i.get_width() / 2
    y=i.get_height()
    snplot.annotate(percentage,(x,y),ha='center',va='center',xytext=(0,10),textcoords = 'offset points')

# %%
sns.FacetGrid(df,hue='target',size=6).map(sns.distplot,'trestbps').add_legend()
plt.show()

# %%
sns.FacetGrid(df,hue='target',size=6).map(sns.distplot,'chol').add_legend()
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
snplot =sns.countplot(data=df,x='fbs',hue='target')
for i in snplot.patches:
    percentage = '{:.2f}%'.format(100*i.get_height()/len(df['fbs']))
    x = i.get_x() + i.get_width() / 2
    y=i.get_height()
    snplot.annotate(percentage,(x,y),ha='center',va='center',xytext=(0,10),textcoords = 'offset points')

# %%
snplot =sns.countplot(data=df,x='restecg',hue='target')
for i in snplot.patches:
    percentage = '{:.2f}%'.format(100*i.get_height()/len(df['restecg']))
    x = i.get_x() + i.get_width() / 2
    y=i.get_height()
    snplot.annotate(percentage,(x,y),ha='center',va='center',xytext=(0,10),textcoords = 'offset points')

# %%
sns.FacetGrid(df,hue='target',size=6).map(sns.distplot,'thalach').add_legend()
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
snplot =sns.countplot(data=df,x='exang',hue='target')
for i in snplot.patches:
    percentage = '{:.2f}%'.format(100*i.get_height()/len(df['exang']))
    x = i.get_x() + i.get_width() / 2
    y=i.get_height()
    snplot.annotate(percentage,(x,y),ha='center',va='center',xytext=(0,10),textcoords = 'offset points')

# %%
sns.FacetGrid(df,hue='target',size=6).map(sns.distplot,'oldpeak').add_legend()
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
snplot =sns.countplot(data=df,x='slope',hue='target')
for i in snplot.patches:
    percentage = '{:.2f}%'.format(100*i.get_height()/len(df['slope']))
    x = i.get_x() + i.get_width() / 2
    y=i.get_height()
    snplot.annotate(percentage,(x,y),ha='center',va='center',xytext=(0,10),textcoords = 'offset points')

# %%
snplot =sns.countplot(data=df,x='thal',hue='target')
for i in snplot.patches:
    percentage = '{:.0f}%'.format(100*i.get_height()/len(df['thal']))
    x = i.get_x() + i.get_width() / 2
    y=i.get_height()
    snplot.annotate(percentage,(x,y),ha='center',va='center',xytext=(0,10),textcoords = 'offset points')

# %%
df['thal'].value_counts()
# Out:
# 2    166
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64
